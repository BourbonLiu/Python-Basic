# %%
import os, fnmatch, glob, re
import pandas as pd

# %%
os.getcwd()                                 # 查看目前工作目錄
# Out:
# 'D:\\JupyterNotebook\\data_analysis'

# %%
path = "./C-MAPSS"
fnames = os.listdir(path); fnames          # 列出C-MAPSS裡所有的檔案
# Out:
# ['description.txt',
#  'Icon_',
#  'Image_001.png',
#  'Image_002.png',
#  'ReadMe.pdf',
#  'readme.txt',
#  'RUL_FD001.txt',
#  'RUL_FD002.txt',
#  'RUL_FD003.txt',
#  'RUL_FD004.txt',
#  'test_FD001.txt',
#  'test_FD002.txt',
#  'test_FD003.txt',
#  'test_FD004.txt',
#  'train_FD001.txt',
#  'train_FD002.txt',
#  'train_FD003.txt',
#  'train_FD004.txt']

# %%
pattern1 = "train*"
for file in fnames:
    if fnmatch.fnmatch(file, pattern1):
        print(file)
# Out:
# train_FD001.txt
# train_FD002.txt
# train_FD003.txt
# train_FD004.txt

# %%
files = [i for i in glob.glob('./C-MAPSS/train*.txt')]          # glob()可以輸入路徑
files
# Out:
# ['./C-MAPSS\\train_FD001.txt',
#  './C-MAPSS\\train_FD002.txt',
#  './C-MAPSS\\train_FD003.txt',
#  './C-MAPSS\\train_FD004.txt']

# %%
trains = [pd.read_csv(f, sep = ' ', header = None, usecols = range(26), names = colnames) for f in files]; trains
# Out:
# [       unitNo  cycles  opera1  opera2  opera3      T2     T24      T30  \
#  0           1       1 -0.0007 -0.0004   100.0  518.67  641.82  1589.70
#  1           1       2  0.0019 -0.0003   100.0  518.67  642.15  1591.82
#  2           1       3 -0.0043  0.0003   100.0  518.67  642.35  1587.99
#  3           1       4  0.0007  0.0000   100.0  518.67  642.35  1582.79
#  4           1       5 -0.0019 -0.0002   100.0  518.67  642.37  1582.85
#  ...       ...     ...     ...     ...     ...     ...     ...      ...
#  20626     100     196 -0.0004 -0.0003   100.0  518.67  643.49  1597.98
#  20627     100     197 -0.0016 -0.0005   100.0  518.67  643.54  1604.50
#  20628     100     198  0.0004  0.0000   100.0  518.67  643.42  1602.46
#  20629     100     199 -0.0011  0.0003   100.0  518.67  643.23  1605.26
#  20630     100     200 -0.0032 -0.0005   100.0  518.67  643.85  1600.38
#
#             T50     P2  ...     phi      NRf      NRc     BPR  farB  htBleed  \
# ...

# %%
train1 = pd.read_csv(files[1], sep = ' ', header = None); train1
# Out:
#         0    1        2       3      4       5       6        7        8   \
# 0        1    1  34.9983  0.8400  100.0  449.44  555.32  1358.61  1137.23
# 1        1    2  41.9982  0.8408  100.0  445.00  549.90  1353.22  1125.78
# 2        1    3  24.9988  0.6218   60.0  462.54  537.31  1256.76  1047.45
# 3        1    4  42.0077  0.8416  100.0  445.00  549.51  1354.03  1126.38
# 4        1    5  25.0005  0.6203   60.0  462.54  537.07  1257.71  1047.93
# ...    ...  ...      ...     ...    ...     ...     ...      ...      ...
# 53754  260  312  20.0037  0.7000  100.0  491.19  608.79  1495.60  1269.51
# 53755  260  313  10.0022  0.2510  100.0  489.05  605.81  1514.32  1324.12
# 53756  260  314  25.0041  0.6200   60.0  462.54  537.48  1276.24  1057.92
# 53757  260  315  25.0033  0.6220   60.0  462.54  537.84  1272.95  1066.30
# 53758  260  316  35.0036  0.8400  100.0  449.44  556.64  1374.61  1145.52
#
#           9   ...       18       19    20   21    22      23     24       25  \
# ...

# %%
colnames = ["unitNo", "cycles","opera1","opera2","opera3","T2","T24","T30","T50","P2","P15","P30","Nf","Nc","epr","Ps30","phi","NRf","NRc","BPR","farB","htBleed","Nf_dmd","PCNfr_dmd","W31","W32"]
train1 = pd.read_csv(files[1], sep = ' ', header = None, usecols = range(26), names = colnames); train1
# Out:
#        unitNo  cycles   opera1  opera2  opera3      T2     T24      T30  \
# 0           1       1  34.9983  0.8400   100.0  449.44  555.32  1358.61
# 1           1       2  41.9982  0.8408   100.0  445.00  549.90  1353.22
# 2           1       3  24.9988  0.6218    60.0  462.54  537.31  1256.76
# 3           1       4  42.0077  0.8416   100.0  445.00  549.51  1354.03
# 4           1       5  25.0005  0.6203    60.0  462.54  537.07  1257.71
# ...       ...     ...      ...     ...     ...     ...     ...      ...
# 53754     260     312  20.0037  0.7000   100.0  491.19  608.79  1495.60
# 53755     260     313  10.0022  0.2510   100.0  489.05  605.81  1514.32
# 53756     260     314  25.0041  0.6200    60.0  462.54  537.48  1276.24
# 53757     260     315  25.0033  0.6220    60.0  462.54  537.84  1272.95
# 53758     260     316  35.0036  0.8400   100.0  449.44  556.64  1374.61
#
#            T50     P2  ...     phi      NRf      NRc      BPR  farB  htBleed  \
# ...

# %%
# 把所有資料合併在一起
train_all = pd.concat(trains); train_all
# Out:
#        unitNo  cycles   opera1  opera2  opera3      T2     T24      T30  \
# 0           1       1  -0.0007 -0.0004   100.0  518.67  641.82  1589.70
# 1           1       2   0.0019 -0.0003   100.0  518.67  642.15  1591.82
# 2           1       3  -0.0043  0.0003   100.0  518.67  642.35  1587.99
# 3           1       4   0.0007  0.0000   100.0  518.67  642.35  1582.79
# 4           1       5  -0.0019 -0.0002   100.0  518.67  642.37  1582.85
# ...       ...     ...      ...     ...     ...     ...     ...      ...
# 61244     249     251   9.9998  0.2500   100.0  489.05  605.33  1516.36
# 61245     249     252   0.0028  0.0015   100.0  518.67  643.42  1598.92
# 61246     249     253   0.0029  0.0000   100.0  518.67  643.68  1607.72
# 61247     249     254  35.0046  0.8400   100.0  449.44  555.77  1381.29
# 61248     249     255  42.0030  0.8400   100.0  445.00  549.85  1369.75
#
#            T50     P2  ...     phi      NRf      NRc     BPR  farB  htBleed  \
# ...
